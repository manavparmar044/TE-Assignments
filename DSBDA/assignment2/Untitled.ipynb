# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('academic_performance.csv')
df.head()
# Out:
#    StudentID       Name  MathScore  ScienceScore  EnglishScore  Attendance
# 0          1  Student_1         78          59.0          68.0          60
# 1          2  Student_2         91          88.0          65.0          90
# 2          3  Student_3         68          91.0          57.0          90
# 3          4  Student_4         54          68.0          79.0          80
# 4          5  Student_5         82          74.0          68.0          90

# %%
df.isnull().sum()
# Out:
# StudentID       0
# Name            0
# MathScore       0
# ScienceScore    0
# EnglishScore    2
# Attendance      0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# StudentID       0
# Name            0
# MathScore       0
# ScienceScore    0
# EnglishScore    0
# Attendance      0
# dtype: int64

# %%
fig,axes = plt.subplots(1,3, figsize = (15,5))
sns.boxplot(data = df['MathScore'], ax = axes[0])
sns.boxplot(data = df['ScienceScore'], ax = axes[1])
sns.boxplot(data = df['EnglishScore'], ax = axes[2])
# Out:
# <Axes: ylabel='EnglishScore'>

# %%
fig,axes = plt.subplots(1,3, figsize = (15,5))
sns.histplot(data = df['MathScore'], ax = axes[0])
sns.histplot(data = df['ScienceScore'], ax = axes[1])
sns.histplot(data = df['EnglishScore'], ax = axes[2])
# Out:
# <Axes: xlabel='EnglishScore', ylabel='Count'>

# %%
def detect_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = column[(column < lower_bound) | (column > upper_bound)]
    return outliers

math_ol = detect_outliers(df["MathScore"])
print(math_ol)
# Out:
# Series([], Name: MathScore, dtype: int64)
